# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('C:\\Users\irumj\OneDrive\Desktop\DS\Python\\WA_Fn-UseC_-HR-Employee-Attrition.csv')
df
# Out:
#       Index  Age Attrition     BusinessTravel  DailyRate  \
# 0         1   41       Yes      Travel_Rarely       1102
# 1         2   49        No  Travel_Frequently        279
# 2         3   37       Yes      Travel_Rarely       1373
# 3         4   33        No  Travel_Frequently       1392
# 4         5   27        No      Travel_Rarely        591
# ...     ...  ...       ...                ...        ...
# 1465   1466   36        No  Travel_Frequently        884
# 1466   1467   39        No      Travel_Rarely        613
# 1467   1468   27        No      Travel_Rarely        155
# 1468   1469   49        No  Travel_Frequently       1023
# 1469   1470   34        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 1     Research & Development                 8          1  Life Sciences
# ...

# %%
df.head(10)
# Out:
#    Index  Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      1   41       Yes      Travel_Rarely       1102                   Sales
# 1      2   49        No  Travel_Frequently        279  Research & Development
# 2      3   37       Yes      Travel_Rarely       1373  Research & Development
# 3      4   33        No  Travel_Frequently       1392  Research & Development
# 4      5   27        No      Travel_Rarely        591  Research & Development
# 5      6   32        No  Travel_Frequently       1005  Research & Development
# 6      7   59        No      Travel_Rarely       1324  Research & Development
# 7      8   30        No      Travel_Rarely       1358  Research & Development
# 8      9   38        No  Travel_Frequently        216  Research & Development
# 9     10   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  ...  \
# ...

# %%
df.tail()
# Out:
#       Index  Age Attrition     BusinessTravel  DailyRate  \
# 1465   1466   36        No  Travel_Frequently        884
# 1466   1467   39        No      Travel_Rarely        613
# 1467   1468   27        No      Travel_Rarely        155
# 1468   1469   49        No  Travel_Frequently       1023
# 1469   1470   34        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 1465              1  ...                         3             80
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1470, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Index                     1470 non-null   int64
#  1   Age                       1470 non-null   int64
#  2   Attrition                 1470 non-null   object
#  3   BusinessTravel            1470 non-null   object
#  4   DailyRate                 1470 non-null   int64
#  5   Department                1470 non-null   object
#  6   DistanceFromHome          1470 non-null   int64
#  7   Education                 1470 non-null   int64
#  8   EducationField            1470 non-null   object
#  9   EmployeeCount             1470 non-null   int64
#  10  EmployeeNumber            1470 non-null   int64
#  11  EnvironmentSatisfaction   1470 non-null   int64
#  12  Gender                    1470 non-null   object
#  13  HourlyRate                1470 non-null   int64
# ...

# %%
df.shape
# Out:
# (1470, 36)

# %%
df.describe()
# Out:
#              Index          Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean    735.500000    36.923810   802.485714          9.192517     2.912925
# std     424.496761     9.135373   403.509100          8.106864     1.024165
# min       1.000000    18.000000   102.000000          1.000000     1.000000
# 25%     368.250000    30.000000   465.000000          2.000000     2.000000
# 50%     735.500000    36.000000   802.000000          7.000000     3.000000
# 75%    1102.750000    43.000000  1157.000000         14.000000     4.000000
# max    1470.000000    60.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1470.0     1470.000000              1470.000000  1470.000000
# mean             1.0     1024.865306                 2.721769    65.891156
# ...

# %%
df.describe(include=['object'])
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
df.describe(include=['bool','object'])
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
df.columns
# Out:
# Index(['Index', 'Age', 'Attrition', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
#        'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Index                        int64
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# ...

# %%
df['EducationField'].unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
df['EducationField'].nunique()
# Out:
# 6

# %%
for column in df:
    print(column,df[column].nunique())
    print('.....................................')
# Out:
# Index 1470
# .....................................
# Age 43
# .....................................
# Attrition 2
# .....................................
# BusinessTravel 3
# .....................................
# DailyRate 886
# .....................................
# Department 3
# .....................................
# DistanceFromHome 29
# .....................................
# Education 5
# .....................................
# EducationField 6
# .....................................
# EmployeeCount 1
# .....................................
# EmployeeNumber 1470
# .....................................
# EnvironmentSatisfaction 4
# .....................................
# Gender 2
# .....................................
# HourlyRate 71
# .....................................
# JobInvolvement 4
# .....................................
# JobLevel 5
# .....................................
# JobRole 9
# .....................................
# JobSatisfaction 4
# ...

# %%
df['EducationField'].value_counts()
# Out:
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64

# %%
df[['EducationField','StockOptionLevel']].value_counts()
# Out:
# EducationField    StockOptionLevel
# Life Sciences     0                   259
#                   1                   253
# Medical           0                   202
#                   1                   172
# Marketing         1                    66
# Life Sciences     2                    65
# Marketing         0                    63
# Technical Degree  1                    59
#                   0                    57
# Medical           2                    54
# Other             0                    40
# Medical           3                    36
# Other             1                    33
# Life Sciences     3                    29
# Marketing         2                    21
# Human Resources   1                    13
# Technical Degree  2                    11
# Human Resources   0                    10
# Marketing         3                     9
# Other             2                     7
# Technical Degree  3                     5
# ...

# %%
df[df['Attrition']=='Yes']
# Out:
#       Index  Age Attrition     BusinessTravel  DailyRate  \
# 0         1   41       Yes      Travel_Rarely       1102
# 2         3   37       Yes      Travel_Rarely       1373
# 14       15   28       Yes      Travel_Rarely        103
# 21       22   36       Yes      Travel_Rarely       1218
# 24       25   34       Yes      Travel_Rarely        699
# ...     ...  ...       ...                ...        ...
# 1438   1439   23       Yes  Travel_Frequently        638
# 1442   1443   29       Yes      Travel_Rarely       1092
# 1444   1445   56       Yes      Travel_Rarely        310
# 1452   1453   50       Yes  Travel_Frequently        878
# 1461   1462   50       Yes      Travel_Rarely        410
#
#                   Department  DistanceFromHome  Education    EducationField  \
# 0                      Sales                 1          2     Life Sciences
# 2     Research & Development                 2          2             Other
# ...

# %%
df
# Out:
#       Index  Age Attrition     BusinessTravel  DailyRate  \
# 0         1   41       Yes      Travel_Rarely       1102
# 1         2   49        No  Travel_Frequently        279
# 2         3   37       Yes      Travel_Rarely       1373
# 3         4   33        No  Travel_Frequently       1392
# 4         5   27        No      Travel_Rarely        591
# ...     ...  ...       ...                ...        ...
# 1465   1466   36        No  Travel_Frequently        884
# 1466   1467   39        No      Travel_Rarely        613
# 1467   1468   27        No      Travel_Rarely        155
# 1468   1469   49        No  Travel_Frequently       1023
# 1469   1470   34        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 1     Research & Development                 8          1  Life Sciences
# ...

# %%
df.select_dtypes(include='number').groupby(['WorkLifeBalance']).mean()
# Out:
#                       Index        Age   DailyRate  DistanceFromHome  \
# WorkLifeBalance
# 1                727.487500  37.287500  812.100000          9.425000
# 2                736.337209  37.188953  827.459302          9.325581
# 3                731.709966  36.849944  798.409854          9.277716
# 4                759.928105  36.568627  765.098039          8.274510
#
#                  Education  EmployeeCount  EmployeeNumber  \
# WorkLifeBalance
# 1                 2.975000            1.0     1014.237500
# 2                 2.857558            1.0     1026.511628
# 3                 2.927212            1.0     1019.240761
# 4                 2.921569            1.0     1059.549020
#
#                  EnvironmentSatisfaction  HourlyRate  JobInvolvement  ...  \
# WorkLifeBalance                                                       ...
# 1                               2.650000   63.800000        2.737500  ...
# ...

# %%
df.groupby(['WorkLifeBalance'])['HourlyRate'].mean()
# Out:
# WorkLifeBalance
# 1    63.800000
# 2    66.502907
# 3    66.090705
# 4    64.444444
# Name: HourlyRate, dtype: float64

# %%
df.groupby(['YearsInCurrentRole'])[['Age','HourlyRate']].mean()
# Out:
#                           Age  HourlyRate
# YearsInCurrentRole
# 0                   35.065574   66.581967
# 1                   35.035088   70.982456
# 2                   35.505376   66.161290
# 3                   36.570370   64.237037
# 4                   37.346154   65.817308
# 5                   34.111111   70.833333
# 6                   41.621622   63.972973
# 7                   37.725225   64.788288
# 8                   37.606742   63.483146
# 9                   40.805970   64.373134
# 10                  40.482759   68.620690
# 11                  40.636364   67.454545
# 12                  41.700000   64.100000
# 13                  42.357143   63.071429
# 14                  39.090909   68.454545
# 15                  45.000000   61.375000
# 16                  45.428571   82.142857
# 17                  45.750000   60.750000
# 18                  51.500000   58.000000

# %%
dfgf=pd.DataFrame(df.groupby(['JobRole']).agg({'Age':[np.mean,np.std],'HourlyRate':[np.mean,'count'],'Education':'nunique'}))
dfgf
# Out:
#                                  Age           HourlyRate       Education
#                                 mean       std       mean count   nunique
# JobRole
# Healthcare Representative  39.809160  8.200483  66.839695   131         5
# Human Resources            35.500000  7.937254  64.173077    52         5
# Laboratory Technician      34.096525  8.419382  66.683398   259         5
# Manager                    46.764706  6.941305  66.833333   102         5
# Manufacturing Director     38.296552  8.622584  65.006897   145         5
# Research Director          44.000000  7.923687  63.762500    80         5
# Research Scientist         34.236301  8.592472  66.708904   292         5
# Sales Executive            36.889571  8.092546  65.438650   326         5
# Sales Representative       30.361446  8.513373  64.337349    83         4

# %%
    df['Age']
# Out:
# 0       41
# 1       49
# 2       37
# 3       33
# 4       27
#         ..
# 1465    36
# 1466    39
# 1467    27
# 1468    49
# 1469    34
# Name: Age, Length: 1470, dtype: int64

# %%
df['Agerange1']=pd.qcut(df["Age"],q=4)
print(df[['Age','Agerange1']])
# Out:
#       Age       Agerange1
# 0      41    (36.0, 43.0]
# 1      49    (43.0, 60.0]
# 2      37    (36.0, 43.0]
# 3      33    (30.0, 36.0]
# 4      27  (17.999, 30.0]
# ...   ...             ...
# 1465   36    (30.0, 36.0]
# 1466   39    (36.0, 43.0]
# 1467   27  (17.999, 30.0]
# 1468   49    (43.0, 60.0]
# 1469   34    (30.0, 36.0]
#
# [1470 rows x 2 columns]

# %%
bin_labels_5 = ['17-30', '30-36', '36-43', '43-60']
df['age ranges 3'] = pd.qcut(df["Age"],
                              q=[0, .25, .5, .75,1],
                              labels=bin_labels_5)
df.head()
# Out:
#    Index  Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      1   41       Yes      Travel_Rarely       1102                   Sales
# 1      2   49        No  Travel_Frequently        279  Research & Development
# 2      3   37       Yes      Travel_Rarely       1373  Research & Development
# 3      4   33        No  Travel_Frequently       1392  Research & Development
# 4      5   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  ...  \
# 0                 1          2  Life Sciences              1  ...
# 1                 8          1  Life Sciences              1  ...
# 2                 2          2          Other              1  ...
# 3                 3          4  Life Sciences              1  ...
# 4                 2          1        Medical              1  ...
#
#    StandardHours  StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# ...

# %%
df['Agerange2']=pd.qcut(df["Age"],q=10,precision=4)
print(df['Agerange2'])
print(df[['Age','Agerange2']])
# Out:
# 0       (38.0, 41.0]
# 1       (45.0, 50.0]
# 2       (36.0, 38.0]
# 3       (31.0, 34.0]
# 4       (26.0, 29.0]
#             ...
# 1465    (34.0, 36.0]
# 1466    (38.0, 41.0]
# 1467    (26.0, 29.0]
# 1468    (45.0, 50.0]
# 1469    (31.0, 34.0]
# Name: Agerange2, Length: 1470, dtype: category
# Categories (10, interval[float64, right]): [(17.9999, 26.0] < (26.0, 29.0] < (29.0, 31.0] < (31.0, 34.0] ... (38.0, 41.0] < (41.0, 45.0] < (45.0, 50.0] < (50.0, 60.0]]
#       Age     Agerange2
# 0      41  (38.0, 41.0]
# 1      49  (45.0, 50.0]
# 2      37  (36.0, 38.0]
# 3      33  (31.0, 34.0]
# 4      27  (26.0, 29.0]
# ...   ...           ...
# 1465   36  (34.0, 36.0]
# 1466   39  (38.0, 41.0]
# 1467   27  (26.0, 29.0]
# 1468   49  (45.0, 50.0]
# 1469   34  (31.0, 34.0]
#
# [1470 rows x 2 columns]

# %%
df['Agerange5']=pd.qcut(df["Age"],q=5,precision=0)
print(df['Agerange5'])
# Out:
# 0       (38.0, 45.0]
# 1       (45.0, 60.0]
# 2       (34.0, 38.0]
# 3       (29.0, 34.0]
# 4       (17.0, 29.0]
#             ...
# 1465    (34.0, 38.0]
# 1466    (38.0, 45.0]
# 1467    (17.0, 29.0]
# 1468    (45.0, 60.0]
# 1469    (29.0, 34.0]
# Name: Agerange5, Length: 1470, dtype: category
# Categories (5, interval[float64, right]): [(17.0, 29.0] < (29.0, 34.0] < (34.0, 38.0] < (38.0, 45.0] < (45.0, 60.0]]
